# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
table1 = pd.read_excel('C:\\Users\\kongzi\\Desktop\\数据\\Table12019各省企业存活数量.xlsx')

# %%
table1.head()
# Out:
#              列1        列2
# 0      Province  Quantity
# 1  Heilongjiang      43.6
# 2         Jilin      44.4
# 3      Liaoning      76.1
# 4       Beijing     118.3

# %%
table2 = pd.read_excel('C:\\Users\\kongzi\\Desktop\\数据\\Table2——2009 - 2018年四个经济区域企业增量变化趋势.xlsx')

# %%
table2.head()
# Out:
#    Year  Eastern Region  Central Region  Northeastern Region  Western Region
# 0  2009             7.9             4.4                  3.3             2.3
# 1  2010             9.4             5.0                  3.6             2.6
# 2  2011            10.3             5.6                  3.8             2.9
# 3  2012             9.9             5.7                  3.6             3.1
# 4  2013            12.7             7.2                  4.6             3.7

# %%
table3 = pd.read_excel('C:\\Users\\kongzi\\Desktop\\数据\\Table3——北京、上海、广州、深圳及部分二线城市企业存废分布数据.xlsx')

# %%
table3.head()
# Out:
#         City  Quantity of Newly_established Enterprises from 2009 to 2018  \
# 0   Shanghai                                              204.8
# 1   Shenzhen                                              203.1
# 2    Beijing                                              152.1
# 3  Guangzhou                                              110.2
# 4  Chongqing                                               97.5
#
#    Quantity of Surviving Enterprises in 2019   \
# 0                                       157.4
# 1                                       174.1
# 2                                       118.3
# 3                                        89.6
# 4                                        69.8
#
#    Quantity of Cnacelled Enterprises from 2009 to 2018
# 0                                               47.4
# 1                                               29.0
# 2                                               33.8
# 3                                               20.6
# ...

# %%
table4 = pd.read_excel('C:\\Users\\kongzi\\Desktop\\数据\\Table3——北京、上海、广州、深圳及部分二线城市企业存废分布数据.xlsx')

# %%
table4.head()
# Out:
#         City  Quantity of Newly_established Enterprises from 2009 to 2018  \
# 0   Shanghai                                              204.8
# 1   Shenzhen                                              203.1
# 2    Beijing                                              152.1
# 3  Guangzhou                                              110.2
# 4  Chongqing                                               97.5
#
#    Quantity of Surviving Enterprises in 2019   \
# 0                                       157.4
# 1                                       174.1
# 2                                       118.3
# 3                                        89.6
# 4                                        69.8
#
#    Quantity of Cnacelled Enterprises from 2009 to 2018
# 0                                               47.4
# 1                                               29.0
# 2                                               33.8
# 3                                               20.6
# ...

# %%
table5 = pd.read_excel('C:\\Users\\kongzi\\Desktop\\数据\\Table5_部分二线城市2019年常住人口及存活企业数量数据.xlsx')

# %%
table5.head()
# Out:
#         City  Quantity of Surviving Enterprises in 2019 Unit:10000  \
# 0   Shanghai                                              157.4
# 1   Shenzhen                                              174.1
# 2    Beijing                                              118.3
# 3  Guangzhou                                               89.6
# 4  Chongqing                                               69.8
#
#    Resident Population in 2019 Unit:1000
# 0                                2419.70
# 1                                1190.84
# 2                                2172.90
# 3                                1404.35
# 4                                 683.07
